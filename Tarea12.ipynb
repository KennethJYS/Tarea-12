# %% [markdown]
# # Tarea 12

# %% [markdown]
# ### Kenneth Yar

# %%
# %load_ext autoreload
import numpy as np
import math
from src import ODE_euler, ODE_euler_nth
import matplotlib.pyplot as plt
# Out:
# [02-08 23:33:54][INFO] 2025-02-08 23:33:54.662766
# [02-08 23:33:54][INFO] User| 2025-02-08 23:33:54.667278
# [02-08 23:33:54][INFO] 2025-02-08 23:33:54.671094
# [02-08 23:33:54][INFO] User| 2025-02-08 23:33:54.674860

# %% [markdown]
# ## Ejercicio 3

# %% [markdown]
# a

# %%
# %autoreload 2
y_der = lambda t, y: y/t - (y/t)**2
y_init = 1

ys2a, ts2a, h = ODE_euler(a = 1, b = 2, f = y_der, y_t0 = y_init, N = 10)

print(f"El valor de h es: {h}")

plt.plot(ts2a, ys2a, marker='o', linestyle='-', label='Método de Euler')

plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución de la EDO con Euler')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# El valor de h es: 0.1

# %% [markdown]
# b

# %%
# %autoreload 2
y_der = lambda t, y: 1 + y/t + (y/t)**2
y_init = 0

ys2b, ts2b, h = ODE_euler(a = 1, b = 3, f = y_der, y_t0 = y_init, N = 10)

print(f"El valor de h es: {h}")

plt.plot(ts2b, ys2b, marker='o', linestyle='-', label='Método de Euler')

plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución de la EDO con Euler')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# El valor de h es: 0.2

# %% [markdown]
# c

# %%
# %autoreload 2
y_der = lambda t, y: -(y + 1)*(y + 3)
y_init = -2

ys2c, ts2c, h = ODE_euler(a = 0, b = 2, f = y_der, y_t0 = y_init, N = 10)

print(f"El valor de h es: {h}")
plt.plot(ts2c, ys2c, marker='o', linestyle='-', label='Método de Euler')

plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución de la EDO con Euler')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# El valor de h es: 0.2

# %% [markdown]
# d

# %%
# %autoreload 2
y_der = lambda t, y: -5*y + 5*t**2 + 2*t
y_init = 1/3

ys2d, ts2d, h = ODE_euler(a = 0, b = 1, f = y_der, y_t0 = y_init, N = 10)

print(f"El valor de h es: {h}")
plt.plot(ts2d, ys2d, marker='o', linestyle='-', label='Método de Euler')

plt.xlabel('t')
plt.ylabel('y(t)')
plt.title('Solución de la EDO con Euler')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# El valor de h es: 0.1

# %% [markdown]
# ### Ejercicio 4

# %% [markdown]
# a

# %%
# %autoreload 2
def y1(t):
    return t/(1 + math.log(t))

errorReal = np.mean([abs(y(t) - y_aprox) / abs(y(t)) for y_aprox, t in zip(ys2a, ts2a)])
print(f"El error real es: {errorReal}")
# Out:
# El error real es: 0.4026114748989524

# %% [markdown]
# b

# %%
# %autoreload 2
def y2(t):
    return t*math.tan(math.log(t))

errorReal = np.mean([abs(y(t) - y_aprox) / abs(y(t)) for y_aprox, t in zip(ys2b, ts2b)])
print(f"El error real es: {errorReal}")
# Out:
# El error real es: 1.4857714189452615

# %% [markdown]
# c

# %%
# %autoreload 2
def y3(t):
    return - 3 + 2/(1 + math.exp(-2*t))

errorReal = np.mean([abs(y(t) - y_aprox) / abs(y(t)) for y_aprox, t in zip(ys2c, ts2c)])
print(f"El error real es: {errorReal}")
# Out:
# El error real es: 2.0191941754493365

# %% [markdown]
# d

# %%
# %autoreload 2
def y4(t):
    return t**2 + (1/3)*math.exp(-5*t)

errorReal = np.mean([abs(y(t) - y_aprox) / abs(y(t)) for y_aprox, t in zip(ys2d, ts2d)])
print(f"El error real es: {errorReal}")
# Out:
# El error real es: 0.7773952281750381

# %% [markdown]
# ### Ejercicio 5

# %% [markdown]
# a

# %%
res = y1(0.25)
print(res)

res = y1(0.93)
print(res)
# Out:
# -0.6471748623905226
# 1.0027718477462106

# %% [markdown]
# b

# %%
cres = y2(1.25)
print(res)

res = y2(1.93)
print(res)
# Out:
# 1.0027718477462106
# 1.4902277738186658

# %% [markdown]
# c

# %%
res = y3(2.1)
print(res)

res = y3(2.75)
print(res)
# Out:
# -1.0295480633865461
# -1.008140275431792

# %% [markdown]
# d

# %%
res = y4(0.54)
print(res)

res = y4(0.94)
print(res)
# Out:
# 0.3140018375799166
# 0.8866317590338986
